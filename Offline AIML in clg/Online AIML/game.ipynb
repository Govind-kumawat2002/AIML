# %%
! pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
# importing the module
from PIL import Image
import os
  
# importing the image 
im = Image.open("011.jpg")
print("The size of the image before conversion : ", end = "")
print(os.path.getsize("011.jpg"))
  
# converting to jpg
rgb_im = im.convert("RGB")
  
# exporting the image
rgb_im.save("011.jpg")
print("The size of the image after conversion : ", end = "")

print(os.path.getsize("011.jpg"))
# Out:
# The size of the image before conversion : 901676
# The size of the image after conversion : 901652

# %%
img = cv2.imread("011.jpg")
plt.imshow(img)

# %%
cv2.rotate(img, cv2.ROTATE_180)
# Out:
# array([[[ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         ...,
#         [ 8, 11,  9],
#         [ 8, 11,  9],
#         [ 8, 11,  9]],
#
#        [[ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         ...,
#         [ 8, 11,  9],
#         [ 8, 11,  9],
#         [ 8, 11,  9]],
#
#        [[ 3,  3,  3],
#         [ 3,  3,  3],
#         [ 3,  3,  3],
#         ...,
#         [ 8, 11,  9],
#         [ 8, 11,  9],
#         [ 8, 11,  9]],
#
#        ...,
#
#        [[24, 30, 35],
#         [24, 30, 35],
#         [23, 30, 33],
#         ...,
#         [23, 23, 17],
#         [23, 23, 17],
#         [23, 23, 17]],
#
#        [[24, 30, 35],
#         [24, 30, 35],
#         [23, 30, 33],
#         ...,
#         [23, 23, 17],
#         [23, 23, 17],
#         [23, 23, 17]],
#
#        [[24, 30, 35],
#         [24, 30, 35],
#         [23, 30, 33],
#         ...,
#         [23, 23, 17],
#         [23, 23, 17],
#         [23, 23, 17]]], dtype=uint8)

# %%
img = cv2.imread("011.jpg")
cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img)

# %%
img = cv2.imread("011.jpg")
 #cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
plt.imshow(img) 
img_cw_180 = cv2.rotate(img, cv2.ROTATE_180)

# display the rotated image
cv2.imshow("Image rotated by 180 degree", img_cw_180)
cv2.waitKey(0)
cv2.destroyAllWindows()
